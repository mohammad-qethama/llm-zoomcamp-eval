# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ingest import load_faq_data
documents = load_faq_data()

# %%
documents[0]
# Out:
# {'id': '9e508f2212',
#  'course': 'data-engineering-zoomcamp',
#  'section': 'General Course-Related Questions',
#  'question': 'Course: When does the course start?',
#  'answer': "A new cohort runs roughly January–April every year. For the current cohort's exact start date and registration link, check the [course repo README](https://github.com/DataTalksClub/data-engineering-zoomcamp).\n\n- Register via the link in the course repo before the cohort starts.\n- Join the [course Telegram channel](https://t.me/dezoomcamp) for announcements.\n- Join DataTalks.Club's [Slack](https://datatalks.club/docs/general/slack/) and the `#course-data-engineering` channel."}

# %%
documents_llm = [doc for doc in documents if doc["course"] == "llm-zoomcamp"]
len(documents_llm)
# Out:
# 113

# %%
documents_llm[0]
# Out:
# {'id': '74eb249bbf',
#  'course': 'llm-zoomcamp',
#  'section': 'General Course-Related Questions',
#  'question': 'I just discovered the course. Can I still join?',
#  'answer': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.'}

# %%
documents = documents_llm

# %%
doc = documents[0]
print(doc["id"])
print(doc["question"])
print(doc["answer"])
# Out:
# 74eb249bbf
# I just discovered the course. Can I still join?
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.

# %%
from pydantic import BaseModel
class Questions(BaseModel):
    questions:list[str]

# %%
data_gen_instructions = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record.

The output should resemble how people ask questions
on the internet. Not too formal, not too short, not too long.
""".strip()

# %%
data_gen_instructions
# Out:
# "You emulate a student who's taking our course.\nFormulate 5 questions this student might ask based on a FAQ record. The record\nshould contain the answer to the questions, and the questions should be complete and not too short.\nIf possible, use as fewer words as possible from the record.\n\nThe output should resemble how people ask questions\non the internet. Not too formal, not too short, not too long."

# %%
from dotenv import load_dotenv
from google import genai
load_dotenv()
client = genai.Client()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from tqdm.auto import tqdm
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
import json

user_prompt = json.dumps(doc)

# %%
response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents=user_prompt,  # just the user message as a string
    config={
        "system_instruction": data_gen_instructions,  # this replaces the "developer" role
        "response_mime_type": "application/json",
        "response_schema": Questions,
    },
)

# %%
result= response.parsed

# %%
print(result.questions)
# Out:
# ['Is it too late to enroll if I just found out about the course?', 'Can I catch up and still earn a certificate if I join late?', 'Do I need to worry about being behind if I register now?', 'If I start the course today, is there still a chance to get certified?', "What are the requirements for getting a certificate if I'm joining after the start date?"]

# %%
from evaluation_utils import llm_structured

# %%
result, usage = llm_structured(
    client,
    data_gen_instructions,
    user_prompt,
    Questions
)

print(result.questions)
# Out:
# ['Is it too late to sign up for the course now that it has already started?', 'Do I still have a shot at getting a certificate if I join the program this late?', 'What are the rules for latecomers who want to earn a certificate?', 'Can I register late and still complete the project requirements for credit?', 'Is there a deadline for project submissions if I join the course after it officially kicks off?']

# %%
usage.prompt_token_count, usage.candidates_token_count
# Out:
# (174, 89)

# %%
from evaluation_utils import calc_price

# %%
cost = calc_price(usage)

cost
# Out:
# {'input_cost': 0.000261, 'output_cost': 0.000801, 'total_cost': 0.001062}

# %%
records = []

for q in result.questions:
    records.append({
        "question": q,
        "document": doc["id"]
    })

records
# Out:
# [{'question': 'Is it too late to sign up for the course now that it has already started?',
#   'document': '74eb249bbf'},
#  {'question': 'Do I still have a shot at getting a certificate if I join the program this late?',
#   'document': '74eb249bbf'},
#  {'question': 'What are the rules for latecomers who want to earn a certificate?',
#   'document': '74eb249bbf'},
#  {'question': 'Can I register late and still complete the project requirements for credit?',
#   'document': '74eb249bbf'},
#  {'question': 'Is there a deadline for project submissions if I join the course after it officially kicks off?',
#   'document': '74eb249bbf'}]

# %%
from evaluation_utils import llm_structured_retry

# %%
def generate_ground_truth(doc):
    user_prompt = json.dumps(doc)

    out, usage = llm_structured_retry(
        client,
        data_gen_instructions,
        user_prompt,
        Questions
    )

    results = []

    for q in out.questions:
        results.append({
            "question": q,
            "document": doc["id"]
        })

    return results, usage

# %%
from tqdm.auto import tqdm

ground_truth = []
usages = []

for doc in tqdm(documents[:5]):
    records, usage = generate_ground_truth(doc)
    ground_truth.extend(records)
    usages.append(usage)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from concurrent.futures import ThreadPoolExecutor
from evaluation_utils import map_progress

# %%
with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, documents, generate_ground_truth)
# Out:
#   0%|          | 0/113 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[41], line 2
#       1 with ThreadPoolExecutor(max_workers=6) as pool:
# ----> 2     results = map_progress(pool, documents, generate_ground_truth)
#
# File ~/llm-zoomcamp-eval/evaluation_utils.py:138, in map_progress(pool, seq, f)
#     135         futures.append(future)
#     137     for future in futures:
# --> 138         result = future.result()
#     139         results.append(result)
#     141 return results
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[35], line 4, in generate_ground_truth(doc)
#       1 def generate_ground_truth(doc):
#       2     user_prompt = json.dumps(doc)
#       3
# ----> 4     out, usage = llm_structured_retry(
#       5         client,
#       6         data_gen_instructions,
#       7         user_prompt,
#
# File ~/llm-zoomcamp-eval/evaluation_utils.py:4, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/llm-zoomcamp-eval/evaluation_utils.py:44, in llm_structured(client, instructions, user_prompt, output_type, model)
#      40 def llm_structured(
#      41     client, instructions, user_prompt, output_type, model="gemini-3.1-flash-lite"
#      42 ):
# ---> 44     response = client.models.generate_content(
#      45         model=model,
#      46         contents=user_prompt,
#      47         config={
#      48             "system_instruction": instructions,
#      49             "response_mime_type": "application/json",
#      50             "response_schema": output_type,
#      51         },
#      52     )
#      53     return response.parsed, response.usage_metadata
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/models.py:6549, in Models.generate_content(self, model, contents, config)
#    6545   parsed_config_to_call = _extra_utils.get_usage_header(
#    6546       parsed_config_to_call
#    6547   )
#    6548 i += 1
# -> 6549 response = self._generate_content(
#    6550     model=model, contents=contents, config=parsed_config_to_call
#    6551 )
#    6553 if not function_map:
#    6554   break
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/models.py:4977, in Models._generate_content(self, model, contents, config)
#    4974 request_dict = _common.convert_to_dict(request_dict)
#    4975 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4977 response = self._api_client.request(
#    4978     'post', path, request_dict, http_options
#    4979 )
#    4981 if config is not None and getattr(
#    4982     config, 'should_return_http_response', None
#    4983 ):
#    4984   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1650, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1640 def request(
#    1641     self,
#    1642     http_method: str,
#    (...)   1645     http_options: Optional[HttpOptionsOrDict] = None,
#    1646 ) -> SdkHttpResponse:
#    1647   http_request = self._build_request(
#    1648       http_method, path, request_dict, http_options
#    1649   )
# -> 1650   response = self._request(http_request, http_options, stream=False)
#    1651   response_body = (
#    1652       response.response_stream[0] if response.response_stream else ''
#    1653   )
#    1654   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1443, in BaseApiClient._request(self, http_request, http_options, stream)
#    1440     retry = tenacity.Retrying(**retry_kwargs)
#    1441     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1443 return self._retry(self._request_once, http_request, stream)
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1420, in BaseApiClient._request_once(self, http_request, stream)
#    1412   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1413       method=http_request.method,
#    1414       url=http_request.url,
#    (...)   1417       timeout=http_request.timeout,
#    1418   )
#    1419   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1420 errors.APIError.raise_for_response(response)
#    1421 return HttpResponse(
#    1422     response.headers, response if stream else [response.text]
#    1423 )
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~/llm-zoomcamp-eval/.venv/lib/python3.12/site-packages/google/genai/errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     170 """Raises an appropriate APIError subclass based on the status code.
#     171
#     172 Args:
#    (...)    181   APIError: For other error status codes.
#     182 """
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#     186   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-3.1-flash-lite\nPlease retry in 3.960574434s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3.1-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '3s'}]}}
